# %%
import sys, os
sys.path.append(os.path.abspath(".."))

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from src.preprocessing import load_and_clean_data

# Load Data
df = load_and_clean_data(
    "../data/raw/Phishing URLs.csv",
    "../data/raw/URL dataset.csv"
)

print("Dataset Shape:", df.shape)
print(df.head())

print("\nClass Distribution:")
print(df['label'].value_counts())

sns.countplot(x='label', data=df)
plt.title("Class Distribution")
plt.show()

# URL Length Analysis
df['url_length'] = df['url'].apply(len)

plt.figure(figsize=(12,6))

sns.histplot(data=df[df['url_length'] < 150], 
             x='url_length', hue='label', kde=True)

plt.title("URL Length Distribution (Zoomed & Cleaned)")
plt.xlabel("URL Length")
plt.ylabel("Frequency")
plt.show()
# Out:
# Dataset Shape: (504933, 2)
#                                                  url  label
# 0  https://docs.google.com/presentation/d/e/2pacx...      1
# 1    https://btttelecommunniccatiion.weeblysite.com/      1
# 2                        https://kq0hgp.webwave.dev/      1
# 3  https://brittishtele1bt-69836.getresponsesite....      1
# 4         https://bt-internet-105056.weeblysite.com/      1
#
# Class Distribution:
# label
# 0    345738
# 1    159195
# Name: count, dtype: int64
